# %% [markdown]
# # Обработка ошибок в Python

# %% [markdown]
# ### Синтаксические ошибки

# %%
while True print('Hello world')
# Out:
#   File "<ipython-input-1-614901b0e5ee>", line 1
#     while True print('Hello world')
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Исключения

# %%
10 * (1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-9ce172bd90a7> in <module>()
# ----> 1 10 * (1/0)
#
# ZeroDivisionError: division by zero

# %%
4 + spam*3

# %%
'2' + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-4c6dd5170204> in <module>()
# ----> 1 '2' + 2
#
# TypeError: must be str, not int

# %% [markdown]
# ### Ограничения на работу программы

# %%
def summ(*args):
    assert all(list(map(lambda x: isinstance(x, int), args))), \
        "arguments must be int. Passed: {}".format(list(map(type, args)))
    return sum(args)

# %%
summ(1, "1")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-79eb81a4ad0d> in <module>()
# ----> 1 summ(1, "1")
#
# <ipython-input-4-3ac407145d68> in summ(*args)
#       1 def summ(*args):
# ----> 2     assert all(list(map(lambda x: isinstance(x, int), args))),         "arguments must be int. Passed: {}".format(list(map(type, args)))
#       3     return sum(args)
#
# AssertionError: arguments must be int. Passed: [<class 'int'>, <class 'str'>]

# %%
def summ(*args):
    if __debug__:
        if not all(list(map(lambda x: isinstance(x, int), args))):
            raise AssertionError("arguments must be int. Passed: {}".format(list(map(type, args))))
    return a + b

# %%
summ(1, "1")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-79eb81a4ad0d> in <module>()
# ----> 1 summ(1, "1")
#
# <ipython-input-6-aa78de19952d> in summ(*args)
#       2     if __debug__:
#       3         if not all(list(map(lambda x: isinstance(x, int), args))):
# ----> 4             raise AssertionError("arguments must be int. Passed: {}".format(list(map(type, args))))
#       5     return a + b
#
# AssertionError: arguments must be int. Passed: [<class 'int'>, <class 'str'>]

# %% [markdown]
# ### Look before you leap

# %%
def summ(*args):
    def process(args):
        processed = []
        for arg in args:
            if isinstance(arg, str):
                processed.append(int(arg))
            elif isinstance(arg, float):
                processed.append(int(arg))
            elif isinstance(arg, (list, dict, tuple)):
                processed.extend(process(arg))
            elif isinstance(arg, bool):
                processed.append(arg)
            elif isinstance(arg, int):
                processed.append(arg)
            # 100 elif
            else:
                print("Exclude undefined type: {}".format(type(arg)))
        return processed
    return sum(process(args))

# %%
summ(1, [1, 2, 3], "2")
# Out:
# 9

# %%
summ(1, [1, 2, 3], "2q")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-6fe0ef7d9207> in <module>()
# ----> 1 summ(1, [1, 2, 3], "2q")
#
# <ipython-input-8-d8e9df9e3645> in summ(*args)
#      17                 print("Exclude undefined type: {}".format(type(arg)))
#      18         return processed
# ---> 19     return sum(process(args))
#
# <ipython-input-8-d8e9df9e3645> in process(args)
#       4         for arg in args:
#       5             if isinstance(arg, str):
# ----> 6                 processed.append(int(arg))
#       7             elif isinstance(arg, float):
#       8                 processed.append(int(arg))
#
# ValueError: invalid literal for int() with base 10: '2q'

# %% [markdown]
# ### Easier to ask for forgiveness than permission

# %%
def summ(*args):
    def process(arg):
        if isinstance(arg, (list, dict, tuple)):
            return list(map(int, arg))
        return [int(arg)]
    res = []
    for arg in args:
        try:
            res.append(sum(process(arg)))
        except:
            print("Exclude undefined type: {}".format(type(arg)))
    return sum(res)

# %%
summ(1, [1, 2, 3], "2")
# Out:
# 9

# %%
summ(1, [1, 2, 3], "2q")
# Out:
# Exclude undefined type: <class 'str'>
# 7

# %% [markdown]
# ### Обработка исключений

# %%
try:
    k = 1 / 0
except ZeroDivisionError:
    k = 0
print(k)
# Out:
# 0

# %%
# запускать не рекомендуется
try:
    for epoch in range(int()):
        print("Epoch {} passed.".format(epoch))
except KeyboardInterrupt:
    print('Training was stoped.')

# %% [markdown]
# ### try exept else

# %%
def zd(a):
    return a / 0

def ve(a):
    # ValueError
    return int(a)

def caller(f, *args):
    try:
        k = f(*args)
    except ZeroDivisionError:
        k = 0
        print("Handled")
    else:
        print(k)

# %%
caller(zd, 1)
# Out:
# Handled

# %%
caller(ve, "2q")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-d6e30553f1db> in <module>()
# ----> 1 caller(ve, "2q")
#
# <ipython-input-24-0f7237037cd8> in caller(f, *args)
#       8 def caller(f, *args):
#       9     try:
# ---> 10         k = f(*args)
#      11     except ZeroDivisionError:
#      12         k = 0
#
# <ipython-input-24-0f7237037cd8> in ve(a)
#       4 def ve(a):
#       5     # ValueError
# ----> 6     return int(a)
#       7
#       8 def caller(f, *args):
#
# ValueError: invalid literal for int() with base 10: '2q'

# %%
caller(ve, "2")
# Out:
# 2

# %% [markdown]
# ### raise

# %%
from functools import wraps
def calc_errors(func):
    @wraps(func)
    def res(*args):
        try:
            return func(*args)
        except :
            res.error_count += 1
            raise
    res.error_count = 0
    return res
@calc_errors
def zd(a):
    return a / 0

# %%
zd(1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-45-99c722b1b73b> in <module>()
# ----> 1 zd(1)
#
# <ipython-input-44-abe9d63ad39a> in res(*args)
#       4     def res(*args):
#       5         try:
# ----> 6             return func(*args)
#       7         except :
#       8             res.error_count += 1
#
# <ipython-input-44-abe9d63ad39a> in zd(a)
#      12 @calc_errors
#      13 def zd(a):
# ---> 14     return a / 0
#
# ZeroDivisionError: division by zero

# %%
zd.error_count
# Out:
# 1

# %% [markdown]
# ### finally

# %%
from functools import wraps
from collections import Counter

def calc_call_stats(func):
    @wraps(func)
    def res(*args):
        try:
            result = func(*args)
        except :
            res.counts["errors"] += 1
            raise
        else:
            res.counts["successes"] += 1
        finally :
            res.counts["calls"] += 1
        return result
    res.counts = Counter()
    return res
@calc_call_stats
def zd(a):
    return 1 / a

# %%
zd(1)
# Out:
# 1.0

# %%
zd.counts
# Out:
# Counter({'calls': 1, 'successes': 1})

# %%
zd(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-59-6b87f87f4ba3> in <module>()
# ----> 1 zd(0)
#
# <ipython-input-56-64d9d2a404c5> in res(*args)
#       6     def res(*args):
#       7         try:
# ----> 8             result = func(*args)
#       9         except :
#      10             res.counts["errors"] += 1
#
# <ipython-input-56-64d9d2a404c5> in zd(a)
#      19 @calc_call_stats
#      20 def zd(a):
# ---> 21     return 1 / a
#
# ZeroDivisionError: division by zero

# %%
zd.counts
# Out:
# Counter({'calls': 2, 'errors': 1, 'successes': 1})

# %% [markdown]
# ### Доступ к объекту исключения

# %%
try:
    k = 1 / 0
except Exception as e:
    print("something wrong {}.".format(e))
    raise
# Out:
# something wrong division by zero.
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-63-c60dd6dd26c5> in <module>()
#       1 try:
# ----> 2     k = 1 / 0
#       3 except Exception as e:
#       4     print("something wrong {}.".format(e))
#       5     raise
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Несколько except

# %%
import sys
 
try:
    f = open('myfile.txt')
    s = f.readline()
    i = int(s.strip())
except IOError as err:
    print("I/O  error({0}): {1}".format(err.errno, err.strerror))
except ValueError:
    print("Не могу преобразовать данные в целое.")
except:
    print("Неожиданная ошибка:", sys.exc_info()[0])
    raise
# Out:
# I/O  error(2): No such file or directory

# %% [markdown]
# ### Порождение исключений

# %%
def test(x):
    if not isinstance(x, int):
        raise TypeError("test() arg must be int")
    return x + 5

# %%
test("2q")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-60c0f9ce90ab> in <module>()
# ----> 1 test("2q")
#
# <ipython-input-70-4ae88af2265b> in test(x)
#       1 def test(x):
#       2     if not isinstance(x, int):
# ----> 3         raise TypeError("test() arg must be int")
#       4     return x + 5
#
# TypeError: test() arg must be int

# %% [markdown]
# ### Исключения, определённые пользователем

# %%
class MyError(Exception):
    def __init__(self, value):
        self.value = value
    def __str__(self):
        return repr(self.value)

# %%
try:
    raise MyError(2*2)
except MyError as e:
    print('Поймано моё исключение со значением:', e.value)
# Out:
# Поймано моё исключение со значением: 4

# %%
#Собственные исключения
class ShoeError(Exception):
    """Basic exception for errors raised by shoes"""
    pass
class UntiedShoelace(ShoeError):
    """You could fall"""
    pass

class WrongFoot(ShoeError):
    """When you miss left and right"""
    pass

# %% [markdown]
# ### raise from

# %%
try:
    zd(0)
except ZeroDivisionError as e:
    raise TypeError("actually, type error") from e
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-80-5bc0b43730c0> in <module>()
#       1 try:
# ----> 2     zd(0)
#       3 except ZeroDivisionError as e:
#
# <ipython-input-56-64d9d2a404c5> in res(*args)
#       7         try:
# ----> 8             result = func(*args)
#       9         except :
#
# <ipython-input-56-64d9d2a404c5> in zd(a)
#      20 def zd(a):
# ---> 21     return 1 / a
#
# ZeroDivisionError: division by zero
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-5bc0b43730c0> in <module>()
#       2     zd(0)
#       3 except ZeroDivisionError as e:
# ----> 4     raise TypeError("actually, type error") from e
#
# TypeError: actually, type error

# %% [markdown]
# ### Библиотеки для работы с исключениями

# %%
import sys

try:
    k = 1 / 0
except Exception as e:
    exc_info = sys.exc_info()
    tr = sys.last_traceback

# %%
exc_info
# Out:
# (ZeroDivisionError,
#  ZeroDivisionError('division by zero'),
#  <traceback at 0x424f71aac8>)

# %%
tr.tb_frame.f_code
# Out:
# <code object run_code at 0x000000424D442390, file "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2851>

# %%
import traceback

# %%
traceback.extract_tb(tr)
# Out:
# [<FrameSummary file C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py, line 2881 in run_code>,
#  <FrameSummary file <ipython-input-86-cebeed2766e8>, line 9 in <module>>]

# %% [markdown]
# # Контектные менеджеры

# %%
with open("what_is_love.txt", "r") as infile:
    for line in infile:
        print("> {}".format(line))

# %% [markdown]
# ### Собственные контекстные менеджеры

# %%
class File():
    def __init__(self, filename, mode):
        self.filename = filename
        self.mode = mode

    def __enter__(self):
        self.open_file = open(self.filename, self.mode)
        return self.open_file

    def __exit__(self, *args):
        self.open_file.close()

# %%
with File("foo.txt", "w") as infile:
    for _ in range(10000):
        infile.write(’foo’)

# %% [markdown]
# # Модули

# %%
import myprinter

# %%
myprinter.pprint("Some text")
# Out:
# Run this package on windows: "Some text"

# %% [markdown]
# ### Импорт модуля

# %%
import myprinter

# %%
import myprinter as mp

# %%
from myprinter import pprint

# %%
from myprinter import *

# %% [markdown]
# ### Пакеты

# %%
import os


def print_package_tree(path="printer", tab=""):
    # <your code here>
    print(tab, path.split("\\")[-1])
    if os.path.isdir(path):
        listdir = os.listdir(path)
        if listdir:
            for d in listdir:
                print_package_tree(os.path.join(path, d), tab + "\t")

# %%
print_package_tree()
# Out:
#  printer
# 	 linux2
# 		 printer.py
# 	 win32
# 		 printer.py
# 		 __pycache__
# 			 printer.cpython-36.pyc
# 	 __init__.py
# 	 __pycache__
# 		 __init__.cpython-36.pyc

# %%
import os
from printer.printer import pprint

# %%
pprint("test")
# Out:
# Run this package on windows: "test"

# %% [markdown]
# # Регулярные выражения

# %%
import re
res = re.match(r'AV', 'AV Analytics Vidhya AV')
print(res)
print(res.group(0))
# Out:
# <_sre.SRE_Match object; span=(0, 2), match='AV'>
# AV

# %%
print(re.match(r'Analytics', 'AV Analytics Vidhya AV'))
# Out:
# None

# %%
re.search(r'Analytics', 'AV Analytics Vidhya AV')
# Out:
# <_sre.SRE_Match object; span=(3, 12), match='Analytics'>

# %%
re.findall(r'AV', 'AV Analytics Vidhya AV')
# Out:
# ['AV', 'AV']

# %%
re.split(r'y', 'Analytics')
# Out:
# ['Anal', 'tics']

# %%
print(re.split(r'i', 'Analytics Vidhya'))
print(re.split(r'i', 'Analytics Vidhya',maxsplit=1))
# Out:
# ['Analyt', 'cs V', 'dhya']
# ['Analyt', 'cs Vidhya']

# %%
re.sub(r'India', 'the World', 'AV is largest Analytics community of India')
# Out:
# 'AV is largest Analytics community of the World'

# %%
pattern = re.compile('AV')
result = pattern.findall('AV Analytics Vidhya AV')
print(result)
result2 = pattern.findall('AV is largest analytics community of India')
print(result2)
# Out:
# ['AV', 'AV']
# ['AV']
